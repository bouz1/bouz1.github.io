# %%
import numpy as np

# %% [markdown]
# <img width="600" src="data:image/png;base64,..." />

# %%
s=0
t=0
for i in range(1,7):
    for j in range(1,7):
        for k in range(1,7):
            if i+j+k==10: 
                s+=1
            t+=1
s/t
# Out:
# 0.125

# %% [markdown]
# <img width="600" src="data:image/png;base64,..." />

# %%
arr= np.array([1]*6+[100]*4+[1000]*5)
2*1+100
res=[]
for i in range(1000000):
    np.random.shuffle(arr)    
    res.append(arr[:3].sum()==2*1+100)
res= np.array(res)
res.sum()/len(res)
# Out:
# np.float64(0.132214)

# %% [markdown]
# <img width="600" src="data:image/png;base64,..." />

# %%
arr= np.array([1]*6+[100]*4+[1000]*5)
2*1+100
res=[]
for i in range(1000000):
    np.random.shuffle(arr)    
    res.append(arr[:3].sum()>=1000)
res= np.array(res)
res.sum()/len(res)
# Out:
# np.float64(0.73587)

# %% [markdown]
# <img width="600" src="data:image/png;base64,..." />

# %%
# GGFF FFGG GFGF FGFG 
4*0.51**2*0.49**2
# Out:
# 0.24980003999999997

# %%
N=1000000
(np.random.choice(a= [100,1],p= [0.51,0.49], size = (N, 4)).sum(axis=1)==202).sum()/N
# Out:
# np.float64(0.374657)
